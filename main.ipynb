# %%
from Functions import *
from graficos import *

# %%
df = data_clean(url='Books_df.csv')

# %%
"""
Aqui llamamos a la función pero como estamos trabajando con una API tarda alrededor de 10 horas en cargar,
por lo tanto lo ejecutamos una vez y lo guardamos como 'df_origin.csv'
- Las dos ultimas lineas se limpian los valores nulos agregados debido al API y se hace cambio de moneda a euros. 
"""
df_origin= read_api(df)
df_origin = null_values(df_origin)
df_origin = exchange_euro(df_origin)

# %%
df_origin = null_values(df_origin)

# %%
df_origin = exchange_euro(df_origin)

# %%
#Esto se hace excepcionalmente para leer la data
import pandas as pd
df = pd.read_csv('df.csv', index_col= 0 )

# %%
df
# Out:
#                                                   title              author  \
# 0                 The Complete Novel of Sherlock Holmes  Arthur Conan Doyle
# 2                                       The Kite Runner     Khaled Hosseini
# 5     Fantastic Beasts and Where to Find Them: The O...        J.K. Rowling
# 9                                            Screenplay           Syd Field
# 10                                              One Day      David Nicholls
# ...                                                 ...                 ...
# 7461                                          Lucky Hit        Hannah Cowan
# 7464                                       Running Wild         K.A. Tucker
# 7475                               Knight of the Ice 11         Yayoi Ogawa
# 7479                            The People of the Indus       Nikhil Gulati
# 7480          Steve Jobs: The Man Who Thought Different    Karen Blumenthal
#
# ...

# %%
grafic_types(df)

# %%
grafic_genre(df)
# Out:
# c:\Users\andre\anaconda3\envs\envproject\Lib\site-packages\plotly\express\_core.py:1979: FutureWarning:
#
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.

# %%
grafic_rating(df)

# %%
grafic_rated(df)
# Out:
# c:\Users\andre\anaconda3\envs\envproject\Lib\site-packages\plotly\express\_core.py:1979: FutureWarning:
#
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.

# %%
grafic_correl(df)

# %%
grafic_c(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 grafic_c(df)
#
# File c:\Users\andre\OneDrive\Escritorio\Project-Week-3\graficos.py:66, in grafic_c(df)
#      63 def grafic_c(df):
#      64   import seaborn as sns
# ---> 66   df_gender = pd.get_dummies(df['main_genre'])
#      67   df_corr = df.merge(df_gender, how="left", left_index=True, right_index=True)
#      69   sns.pairplot(df_corr.select_dtypes([int, bool, float]))
#
# NameError: name 'pd' is not defined
